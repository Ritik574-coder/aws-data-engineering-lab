# %%
# !aws s3 ls
# Out:
# 2026-04-05 20:37:18 amzn-row-data-bucket-219399225390-ap-south-1-an
# 2026-04-22 04:42:21 databricks-s3-ingest-4ca9f-lambdazipsbucket-08srdcczxpwn
# 2026-07-02 09:38:46 nyc-yellow-taxi-dataset-2026
# 2026-04-22 07:19:36 ritsky-bucket-2025

# %%
# !aws s3 ls s3://ritsky-bucket-2025
# Out:
#                            PRE NYC_taxi_data/
#                            PRE aws-data-engineering-lab/
#                            PRE data_warehouse/
#                            PRE retail_raw_dataset/
# 2026-07-09 17:25:45   12284326 30DayQuakes.json
# 2026-07-09 17:25:44     855395 cust_info.csv
# 2026-07-09 17:25:45      74202 cust_info.orc
# 2026-07-09 17:25:45      97652 cust_info.sql
# 2026-07-09 17:25:45      45475 customers.xml
# 2026-07-09 17:25:45     907221 dbt_log_file.log
# 2026-07-09 17:25:45       2559 fx.html
# 2026-07-09 17:25:45      13876 raw_employees.txt
# 2026-07-09 17:25:45     978944 rides.db
# 2026-07-09 17:25:45     602094 sales_details.parquet
# 2026-07-09 17:25:45       7876 sample_100x8_dataset.xlsx
# 2026-07-09 17:25:45    1252135 taxi.jl
# 2026-07-09 17:25:45      15794 weather.pdf

# %%
# !aws s3 ls s3://ritsky-bucket-2025 --recursive | awk '{print $4}' | tree --fromfile .
# Out:
# .
# ├── 30DayQuakes.json
# ├── aws-data-engineering-lab
# │   ├── athena
# │   │   ├── athena_management.md
# │   │   ├── athena_python_examples.md
# │   │   └── athena_queries.md
# │   ├── aws_backup
# │   │   ├── backup_management.md
# │   │   └── backup_python_examples.md
# │   ├── boto3
# │   │   ├── authentication.md
# │   │   ├── best_practices.md
# │   │   ├── error_handling.md
# │   │   ├── pagination.md
# │   │   ├── retries.md
# │   │   └── session_management.md
# │   ├── cloudformation
# │   │   ├── cloudformation_python_examples.md
# │   │   └── cloudformation_stacks.md
# │   ├── cloudwatch
# │   │   ├── alarms.md
# │   │   ├── cloudwatch_python_examples.md
# │   │   ├── logs.md
# │   │   └── monitoring.md
# │   ├── config
# │   │   └── config_compliance.md
# │   ├── dynamodb
# │   │   ├── dynamodb_operations.md
# │   │   └── dynamodb_python_examples.md
# │   ├── ec2
# │   │   ├── ec2_instance_management.md
# │   │   ├── ec2_key_pairs.md
# ...

# %%
# !aws s3 ls s3://ritsky-bucket-2025/aws-data-engineering-lab --recursive | awk '{print $4}' | tree --fromfile .
# Out:
# .
# └── aws-data-engineering-lab
#     ├── athena
#     │   ├── athena_management.md
#     │   ├── athena_python_examples.md
#     │   └── athena_queries.md
#     ├── aws_backup
#     │   ├── backup_management.md
#     │   └── backup_python_examples.md
#     ├── boto3
#     │   ├── authentication.md
#     │   ├── best_practices.md
#     │   ├── error_handling.md
#     │   ├── pagination.md
#     │   ├── retries.md
#     │   └── session_management.md
#     ├── cloudformation
#     │   ├── cloudformation_python_examples.md
#     │   └── cloudformation_stacks.md
#     ├── cloudwatch
#     │   ├── alarms.md
#     │   ├── cloudwatch_python_examples.md
#     │   ├── logs.md
#     │   └── monitoring.md
#     ├── config
#     │   └── config_compliance.md
#     ├── dynamodb
#     │   ├── dynamodb_operations.md
#     │   └── dynamodb_python_examples.md
#     ├── ec2
#     │   ├── ec2_instance_management.md
#     │   ├── ec2_key_pairs.md
#     │   ├── ec2_python_boto3_examples.md
# ...

# %%
# !aws s3 ls s3://ritsky-bucket-2025 --recursive | awk '{print $4}' | tree --fromfile .
# Out:
# .
# ├── 30DayQuakes.json
# ├── aws-data-engineering-lab
# │   ├── athena
# │   │   ├── athena_management.md
# │   │   ├── athena_python_examples.md
# │   │   └── athena_queries.md
# │   ├── aws_backup
# │   │   ├── backup_management.md
# │   │   └── backup_python_examples.md
# │   ├── boto3
# │   │   ├── authentication.md
# │   │   ├── best_practices.md
# │   │   ├── error_handling.md
# │   │   ├── pagination.md
# │   │   ├── retries.md
# │   │   └── session_management.md
# │   ├── cloudformation
# │   │   ├── cloudformation_python_examples.md
# │   │   └── cloudformation_stacks.md
# │   ├── cloudwatch
# │   │   ├── alarms.md
# │   │   ├── cloudwatch_python_examples.md
# │   │   ├── logs.md
# │   │   └── monitoring.md
# │   ├── config
# │   │   └── config_compliance.md
# │   ├── dynamodb
# │   │   ├── dynamodb_operations.md
# │   │   └── dynamodb_python_examples.md
# │   ├── ec2
# │   │   ├── ec2_instance_management.md
# │   │   ├── ec2_key_pairs.md
# ...

# %%
# !aws s3 ls
# Out:
# 2026-04-05 20:37:18 amzn-row-data-bucket-219399225390-ap-south-1-an
# 2026-04-22 04:42:21 databricks-s3-ingest-4ca9f-lambdazipsbucket-08srdcczxpwn
# 2026-07-02 09:38:46 nyc-yellow-taxi-dataset-2026
# 2026-04-22 07:19:36 ritsky-bucket-2025

# %%
# !aws s3 mb s3://ritsky-data-lake-2026
# Out:
# make_bucket: ritsky-data-lake-2026

# %%
# !aws s3 ls
# Out:
# 2026-04-05 20:37:18 amzn-row-data-bucket-219399225390-ap-south-1-an
# 2026-04-22 04:42:21 databricks-s3-ingest-4ca9f-lambdazipsbucket-08srdcczxpwn
# 2026-07-02 09:38:46 nyc-yellow-taxi-dataset-2026
# 2026-04-22 07:19:36 ritsky-bucket-2025
# 2026-07-10 21:01:36 ritsky-data-lake-2026

# %%
# !aws s3 rb s3://ritsky-data-lake-2026
# Out:
# remove_bucket: ritsky-data-lake-2026

# %%
# !aws s3 ls s3://databricks-s3-ingest-4ca9f-lambdazipsbucket-08srdcczxpwn  --recursive
# Out:
# 2026-04-05 21:32:50    1235676 functions/packages/s3-ingestion/lambda.zip

# %%
# !aws s3 cp \
s3://databricks-s3-ingest-4ca9f-lambdazipsbucket-08srdcczxpwn/functions/packages/s3-ingestion/lambda.zip \
.
# Out:
# download: s3://databricks-s3-ingest-4ca9f-lambdazipsbucket-08srdcczxpwn/functions/packages/s3-ingestion/lambda.zip to ./lambda.zip

# %%
# !aws cloudformation list-stacks
# Out:
# {
#     "StackSummaries": [
#         {
#             "StackId": "arn:aws:cloudformation:ap-south-1:219399225390:stack/databricks-s3-ingest-4ca9f/c94f68c0-3108-11f1-b62e-02dbee891077",
#             "StackName": "databricks-s3-ingest-4ca9f",
#             "TemplateDescription": "Set up resources to ingest data from S3 into your workspace.",
#             "CreationTime": "2026-04-05T16:02:03.988000+00:00",
#             "StackStatus": "CREATE_COMPLETE",
#             "DriftInformation": {
#                 "StackDriftStatus": "NOT_CHECKED"
#             },
#             "LastOperations": [
#                 {
#                     "OperationType": "CREATE_STACK",
#                     "OperationId": "c0746e6b-21ca-4560-b674-7a5faad12c4c"
#                 }
#             ]
#         }
#     ]
# }

# %%
# !aws cloudformation list-stack-resources \
    --stack-name databricks-s3-ingest-4ca9f
# Out:
# {
#     "StackResourceSummaries": [
#         {
#             "LogicalResourceId": "CopyZips",
#             "PhysicalResourceId": "2026/04/05/[$LATEST]41d551037b004095a8847a6067e6df96",
#             "ResourceType": "Custom::CopyZips",
#             "LastUpdatedTimestamp": "2026-04-05T16:02:53.954000+00:00",
#             "ResourceStatus": "CREATE_COMPLETE",
#             "DriftInformation": {
#                 "StackResourceDriftStatus": "NOT_CHECKED"
#             }
#         },
#         {
#             "LogicalResourceId": "CopyZipsFunction",
#             "PhysicalResourceId": "databricks-s3-ingest-4ca9f-CopyZipsFunction-ESez7B0OtTfP",
#             "ResourceType": "AWS::Lambda::Function",
#             "LastUpdatedTimestamp": "2026-04-05T16:02:45.308000+00:00",
#             "ResourceStatus": "CREATE_COMPLETE",
#             "DriftInformation": {
#                 "StackResourceDriftStatus": "NOT_CHECKED"
#             }
#         },
#         {
# ...

# %%
# !aws s3 ls s3://amzn-row-data-bucket-219399225390-ap-south-1-an --recursive
# Out:
# 2026-04-05 21:08:01     134167 raw_customers.csv
# 2026-04-05 21:08:01      17568 raw_employees.csv
# 2026-04-05 21:08:02      55532 raw_inventory_snapshots.csv
# 2026-04-05 21:08:02      14774 raw_products.csv
# 2026-04-05 21:08:03      99846 raw_returns.csv
# 2026-04-05 21:08:04     242945 raw_reviews.csv
# 2026-04-05 21:08:10   11774558 raw_sales_transactions.csv
# 2026-04-05 21:08:14       8664 raw_stores.csv
# 2026-04-05 21:39:04     134167 row_data/raw_customers.csv
# 2026-04-05 21:38:46      17568 row_data/raw_employees.csv
# 2026-04-05 21:38:46      55532 row_data/raw_inventory_snapshots.csv
# 2026-04-05 21:38:46      14774 row_data/raw_products.csv
# 2026-04-05 21:38:47      99846 row_data/raw_returns.csv
# 2026-04-05 21:39:04     242945 row_data/raw_reviews.csv
# 2026-04-05 21:38:59   11774558 row_data/raw_sales_transactions.csv
# 2026-04-05 21:39:03       8664 row_data/raw_stores.csv

# %%
# !aws s3 rb s3://amzn-row-data-bucket-219399225390-ap-south-1-an --force
# Out:
# delete: s3://amzn-row-data-bucket-219399225390-ap-south-1-an/raw_customers.csv
# delete: s3://amzn-row-data-bucket-219399225390-ap-south-1-an/raw_employees.csv
# delete: s3://amzn-row-data-bucket-219399225390-ap-south-1-an/raw_inventory_snapshots.csv
# delete: s3://amzn-row-data-bucket-219399225390-ap-south-1-an/row_data/raw_customers.csv
# delete: s3://amzn-row-data-bucket-219399225390-ap-south-1-an/raw_products.csv
# delete: s3://amzn-row-data-bucket-219399225390-ap-south-1-an/raw_stores.csv
# delete: s3://amzn-row-data-bucket-219399225390-ap-south-1-an/raw_reviews.csv
# delete: s3://amzn-row-data-bucket-219399225390-ap-south-1-an/raw_sales_transactions.csv
# delete: s3://amzn-row-data-bucket-219399225390-ap-south-1-an/row_data/raw_products.csv
# delete: s3://amzn-row-data-bucket-219399225390-ap-south-1-an/row_data/raw_inventory_snapshots.csv
# delete: s3://amzn-row-data-bucket-219399225390-ap-south-1-an/raw_returns.csv
# ...

# %%
# !aws s3 ls s3://nyc-yellow-taxi-dataset-2026 --recursive | awk '{print $4}' | tree -a
# Out:
# .
# ├── s3_basic_commands.md
# ├── s3_bucket_management.md
# ├── s3_command_.ipynb
# ├── s3_file_operations.md
# ├── s3_lifecycle_versioning.md
# ├── s3_python_boto3_examples.md
# ├── s3_security_permissions.md
# └── s3_working_command.md
#
# 1 directory, 8 files

# %%
# !aws s3 ls s3://ritsky-bucket-2025 --recursive | awk '{print $4}' | tree --fromfile .
# Out:
# .
# ├── 30DayQuakes.json
# ├── aws-data-engineering-lab
# │   ├── athena
# │   │   ├── athena_management.md
# │   │   ├── athena_python_examples.md
# │   │   └── athena_queries.md
# │   ├── aws_backup
# │   │   ├── backup_management.md
# │   │   └── backup_python_examples.md
# │   ├── boto3
# │   │   ├── authentication.md
# │   │   ├── best_practices.md
# │   │   ├── error_handling.md
# │   │   ├── pagination.md
# │   │   ├── retries.md
# │   │   └── session_management.md
# │   ├── cloudformation
# │   │   ├── cloudformation_python_examples.md
# │   │   └── cloudformation_stacks.md
# │   ├── cloudwatch
# │   │   ├── alarms.md
# │   │   ├── cloudwatch_python_examples.md
# │   │   ├── logs.md
# │   │   └── monitoring.md
# │   ├── config
# │   │   └── config_compliance.md
# │   ├── dynamodb
# │   │   ├── dynamodb_operations.md
# │   │   └── dynamodb_python_examples.md
# │   ├── ec2
# │   │   ├── ec2_instance_management.md
# │   │   ├── ec2_key_pairs.md
# ...

# %%
# !aws s3 rm s3://ritsky-bucket-2025/30DayQuakes.json
# Out:
# delete: s3://ritsky-bucket-2025/30DayQuakes.json

# %%
# !echo Print object stracture in tree format 
# !aws s3 ls s3://ritsky-bucket-2025 --recursive | awk '{print $4}' | tree --fromfile .
# Out:
# Print object stracture in tree format
# .
# ├── aws-data-engineering-lab
# │   ├── athena
# │   │   ├── athena_management.md
# │   │   ├── athena_python_examples.md
# │   │   └── athena_queries.md
# │   ├── aws_backup
# │   │   ├── backup_management.md
# │   │   └── backup_python_examples.md
# │   ├── boto3
# │   │   ├── authentication.md
# │   │   ├── best_practices.md
# │   │   ├── error_handling.md
# │   │   ├── pagination.md
# │   │   ├── retries.md
# │   │   └── session_management.md
# │   ├── cloudformation
# │   │   ├── cloudformation_python_examples.md
# │   │   └── cloudformation_stacks.md
# │   ├── cloudwatch
# │   │   ├── alarms.md
# │   │   ├── cloudwatch_python_examples.md
# │   │   ├── logs.md
# │   │   └── monitoring.md
# │   ├── config
# │   │   └── config_compliance.md
# │   ├── dynamodb
# │   │   ├── dynamodb_operations.md
# │   │   └── dynamodb_python_examples.md
# │   ├── ec2
# │   │   ├── ec2_instance_management.md
# │   │   ├── ec2_key_pairs.md
# ...

# %%
# !echo removing empty folder in s3 bucket using aws CLI 
# !aws s3 rm s3://ritsky-bucket-2025/NYC_taxi_data/
# Out:
# removing folder in s3 bucket using aws CLI
# delete: s3://ritsky-bucket-2025/NYC_taxi_data/

# %%
# !echo removing folter that have object indside in s3 bucket using aws cli 

# !aws s3 rm s3://ritsky-bucket-2025/data_warehouse/bronze/erp/ --recursive
# Out:
# removing folter that have object indside in s3 bucket using aws cli
# delete: s3://ritsky-bucket-2025/data_warehouse/bronze/erp/CUST_AZ12.csv
# delete: s3://ritsky-bucket-2025/data_warehouse/bronze/erp/PX_CAT_G1V2.csv
# delete: s3://ritsky-bucket-2025/data_warehouse/bronze/erp/LOC_A101.csv

# %%
# !aws s3 ls s3://ritsky-bucket-2025 --recursive | awk '{print $4}' | tree --fromfile .
# Out:
# .
# ├── aws-data-engineering-lab
# │   ├── athena
# │   │   ├── athena_management.md
# │   │   ├── athena_python_examples.md
# │   │   └── athena_queries.md
# │   ├── aws_backup
# │   │   ├── backup_management.md
# │   │   └── backup_python_examples.md
# │   ├── boto3
# │   │   ├── authentication.md
# │   │   ├── best_practices.md
# │   │   ├── error_handling.md
# │   │   ├── pagination.md
# │   │   ├── retries.md
# │   │   └── session_management.md
# │   ├── cloudformation
# │   │   ├── cloudformation_python_examples.md
# │   │   └── cloudformation_stacks.md
# │   ├── cloudwatch
# │   │   ├── alarms.md
# │   │   ├── cloudwatch_python_examples.md
# │   │   ├── logs.md
# │   │   └── monitoring.md
# │   ├── config
# │   │   └── config_compliance.md
# │   ├── dynamodb
# │   │   ├── dynamodb_operations.md
# │   │   └── dynamodb_python_examples.md
# │   ├── ec2
# │   │   ├── ec2_instance_management.md
# │   │   ├── ec2_key_pairs.md
# │   │   ├── ec2_python_boto3_examples.md
# ...

# %%
# !aws s3 mb s3://ritsky-data-lake-2026
# Out:
# make_bucket: ritsky-data-lake-2026

# %%
# !aws s3 mb s3://ritsky-data-lakehouse-2026
# Out:
# make_bucket: ritsky-data-lakehouse-2026

# %%
# %%bash
# echo "========================================"
# echo "Deleting multiple files in S3 bucket using AWS CLI"
# echo "========================================"
#
# for file in \
#     "s3://ritsky-bucket-2025/sales_details.parquet" \
#     "s3://ritsky-bucket-2025/sample_100x8_dataset.xlsx" \
#     "s3://ritsky-bucket-2025/taxi.jl" \
#     "s3://ritsky-bucket-2025/weather.pdf"
# do
#     aws s3 rm "$file"
# done
#
# echo "========================================"
# Out:
# ...
# Deleting multiple files in S3 bucket using AWS CLI
# ...
# delete: s3://ritsky-bucket-2025/sales_details.parquet
# delete: s3://ritsky-bucket-2025/sample_100x8_dataset.xlsx
# delete: s3://ritsky-bucket-2025/taxi.jl
# delete: s3://ritsky-bucket-2025/weather.pdf
# ...

# %%
# %%bash
#
# aws s3 cp /home/ritik/Documents/multiple_file_type \
# s3://ritsky-bucket-2025/multi_file_type \
# --recursive
# Out:
# upload: ../../Documents/multiple_file_type/fx.html to s3://ritsky-bucket-2025/multi_file_type/fx.html
# upload: ../../Documents/multiple_file_type/customers.xml to s3://ritsky-bucket-2025/multi_file_type/customers.xml
# upload: ../../Documents/multiple_fi/s) with 11 file(s) remainingle_type/cust_info.orc to s3://ritsky-bucket-2025/multi_file_type/cust_info.orc
# upload: ../../Documents/multiple_file_type/cust_info.sql to s3://ritsky-bucket-2025/multi_file_type/cust_info.sql
# upload: ../../Documents/multiple_file_type/sample_100x8_dataset.xlsx to s3://ritsky-bucket-2025/multi_file_type/sample_100x8_dataset.xlsx
# upload: ../../Documents/multiple_file_type/raw_employees.txt to s3://ritsky-bucket-2025/multi_file_type/raw_employees.txt
# upload: ../../Documents/multiple_fils) with 7 file(s) remaininge_type/weather.pdf to s3://ritsky-bucket-2025/multi_file_type/weather.pdf
# ...

# %%
# %%bash
#
# aws s3 ls s3://ritsky-bucket-2025 --recursive | awk '{print $4}' | tree --fromfile .
# Out:
# .
# ├── aws-data-engineering-lab
# │   ├── athena
# │   │   ├── athena_management.md
# │   │   ├── athena_python_examples.md
# │   │   └── athena_queries.md
# │   ├── aws_backup
# │   │   ├── backup_management.md
# │   │   └── backup_python_examples.md
# │   ├── boto3
# │   │   ├── authentication.md
# │   │   ├── best_practices.md
# │   │   ├── error_handling.md
# │   │   ├── pagination.md
# │   │   ├── retries.md
# │   │   └── session_management.md
# │   ├── cloudformation
# │   │   ├── cloudformation_python_examples.md
# │   │   └── cloudformation_stacks.md
# │   ├── cloudwatch
# │   │   ├── alarms.md
# │   │   ├── cloudwatch_python_examples.md
# │   │   ├── logs.md
# │   │   └── monitoring.md
# │   ├── config
# │   │   └── config_compliance.md
# │   ├── dynamodb
# │   │   ├── dynamodb_operations.md
# │   │   └── dynamodb_python_examples.md
# │   ├── ec2
# │   │   ├── ec2_instance_management.md
# │   │   ├── ec2_key_pairs.md
# │   │   ├── ec2_python_boto3_examples.md
# ...

# %%
# %%bash
#
# aws s3 rm s3://ritsky-bucket-2025/multi_file_type/ --recursive
# Out:
# delete: s3://ritsky-bucket-2025/multi_file_type/cust_info.csv
# delete: s3://ritsky-bucket-2025/multi_file_type/30DayQuakes.json
# delete: s3://ritsky-bucket-2025/multi_file_type/cust_info.orc
# delete: s3://ritsky-bucket-2025/multi_file_type/sample_100x8_dataset.xlsx
# delete: s3://ritsky-bucket-2025/multi_file_type/taxi.jl
# delete: s3://ritsky-bucket-2025/multi_file_type/weather.pdf
# delete: s3://ritsky-bucket-2025/multi_file_type/sales_details.parquet
# delete: s3://ritsky-bucket-2025/multi_file_type/fx.html
# delete: s3://ritsky-bucket-2025/multi_file_type/dbt_log_file.log
# delete: s3://ritsky-bucket-2025/multi_file_type/rides.db
# delete: s3://ritsky-bucket-2025/multi_file_type/customers.xml
# delete: s3://ritsky-bucket-2025/multi_file_type/cust_info.sql
# delete: s3://ritsky-bucket-2025/multi_file_type/raw_employees.txt

# %%
# %%bash
#
# aws s3 rm s3://ritsky-bucket-2025/data_warehouse/ --recursive
# Out:
# delete: s3://ritsky-bucket-2025/data_warehouse/
# delete: s3://ritsky-bucket-2025/data_warehouse/bronze/crm/
# delete: s3://ritsky-bucket-2025/data_warehouse/bronze/crm/sales_details.csv
# delete: s3://ritsky-bucket-2025/data_warehouse/bronze/crm/prd_info.csv
# delete: s3://ritsky-bucket-2025/data_warehouse/silver/
# delete: s3://ritsky-bucket-2025/data_warehouse/bronze/crm/cust_info.csv
# delete: s3://ritsky-bucket-2025/data_warehouse/gold/
# delete: s3://ritsky-bucket-2025/data_warehouse/bronze/

# %%
# %%bash
# aws s3 cp /home/ritik/Documents/multiple_file_type \
# s3://ritsky-bucket-2025/multi_form_file/ \
# --recursive
# Out:
# upload: ../../Documents/multiple_file_type/fx.html to s3://ritsky-bucket-2025/multi_form_file/fx.html
# upload: ../../Documents/multiple_file_type/raw_employees.txt to s3://ritsky-bucket-2025/multi_form_file/raw_employees.txt
# upload: ../../Documents/multiple_file_type/customers.xml to s3://ritsky-bucket-2025/multi_form_file/customers.xml
# upload: ../../Documents/multiple_file_type/cust_info.sql to s3://ritsky-bucket-2025/multi_form_file/cust_info.sql
# upload: ../../Documents/multiple_fils) with 9 file(s) remainings) with 9 file(s) remaininge_type/cust_info.orc to s3://ritsky-bucket-2025/multi_form_file/cust_info.orc
# upload: ../../Documents/multiple_fils) with 8 file(s) remaininge_type/sample_100x8_dataset.xlsx to s3://ritsky-bucket-2025/multi_form_file/sample_100x8_dataset.xlsx
# upload: ../../Documents/multiple_file_type/weather.pdf to s3://ritsky-bucket-2025/multi_form_file/weather.pdf
# ...

# %%
# %%bash
# aws s3 ls s3://ritsky-bucket-2025/multi_form_file/ --recursive
# Out:
# 2026-07-11 13:23:05   12284326 multi_form_file/30DayQuakes.json
# 2026-07-11 13:23:05     855395 multi_form_file/cust_info.csv
# 2026-07-11 13:23:05      74202 multi_form_file/cust_info.orc
# 2026-07-11 13:23:05      97652 multi_form_file/cust_info.sql
# 2026-07-11 13:23:05      45475 multi_form_file/customers.xml
# 2026-07-11 13:23:05     907221 multi_form_file/dbt_log_file.log
# 2026-07-11 13:23:05       2559 multi_form_file/fx.html
# 2026-07-11 13:23:05      13876 multi_form_file/raw_employees.txt
# 2026-07-11 13:23:05     978944 multi_form_file/rides.db
# 2026-07-11 13:23:05     602094 multi_form_file/sales_details.parquet
# 2026-07-11 13:23:05       7876 multi_form_file/sample_100x8_dataset.xlsx
# 2026-07-11 13:23:05    1252135 multi_form_file/taxi.jl
# 2026-07-11 13:23:05      15794 multi_form_file/weather.pdf

# %%
# %%bash
#
# aws s3 ls s3://ritsky-bucket-2025 --human-readable --summarize
# Out:
#                            PRE aws-data-engineering-lab/
#                            PRE multi_form_file/
#                            PRE retail_raw_dataset/
# 2026-07-09 17:25:44  835.3 KiB cust_info.csv
# 2026-07-09 17:25:45   72.5 KiB cust_info.orc
# 2026-07-09 17:25:45   95.4 KiB cust_info.sql
# 2026-07-09 17:25:45   44.4 KiB customers.xml
# 2026-07-09 17:25:45  886.0 KiB dbt_log_file.log
# 2026-07-09 17:25:45    2.5 KiB fx.html
# 2026-07-09 17:25:45   13.6 KiB raw_employees.txt
# 2026-07-09 17:25:45  956.0 KiB rides.db
#
# Total Objects: 8
#    Total Size: 2.8 MiB

# %%
# %%bash
# aws s3 cp s3://ritsky-bucket-2025/cust_info.csv \
# /home/ritik/Downloads/aws_cli/
# Out:
# download: s3://ritsky-bucket-2025/cust_info.csv to ../../Downloads/aws_cli/cust_info.csv

# %%
# %%bash
#
# aws s3 ls
# Out:
# 2026-04-22 04:42:21 databricks-s3-ingest-4ca9f-lambdazipsbucket-08srdcczxpwn
# 2026-07-02 09:38:46 nyc-yellow-taxi-dataset-2026
# 2026-04-22 07:19:36 ritsky-bucket-2025
# 2026-07-11 08:35:43 ritsky-data-lake-2026
# 2026-07-11 08:36:24 ritsky-data-lakehouse-2026

# %%
# %%bash
# aws s3 cp /home/ritik/Downloads/dataset \
# s3://ritsky-data-lake-2026/bronze/utilization/ \
# --recursive
# Out:
# upload: ../../Downloads/dataset/server_name.csv to s3://ritsky-data-lake-2026/bronze/utilization/server_name.csv
# upload: ../../Downloads/dataset/location_temp.csv to s3://ritsky-data-lake-2026/bronze/utilization/l  ocation_temp.csv
# upload: ../../Downloads/dataset/utilization.csv to s3://ritsky-data-lake-2026/bronze/utilization/utilization.csv
# upload: ../../Downloads/dataset/utilization.json to s3://ritsky-data-lake-2026/bronze/utilization/utilization.json

# %%
# %%bash
#
# aws s3 ls s3://ritsky-data-lake-2026 --recursive | awk '{print $4}' | tree --fromfile .
# Out:
# .
# └── bronze
#     └── utilization
#         ├── location_temp.csv
#         ├── server_name.csv
#         ├── utilization.csv
#         └── utilization.json
#
# 3 directories, 4 files

# %%
# %%bash
#
# aws s3api get-bucket-location --bucket ritsky-data-lake-2026
# Out:
# {
#     "LocationConstraint": "ap-south-1"
# }

# %%
# %%bash
#
# aws s3api head-object \
# --bucket ritsky-data-lake-2026 \
# --key bronze/utilization/server_name.csv
# Out:
# {
#     "AcceptRanges": "bytes",
#     "LastModified": "2026-07-11T15:06:57+00:00",
#     "ContentLength": 772,
#     "ETag": "\"4a460599f4f75323d57171cda3aef7b5\"",
#     "ContentType": "text/csv",
#     "ServerSideEncryption": "AES256",
#     "Metadata": {}
# }

# %%
# %%bash
#
# aws s3api get-bucket-versioning \
# --bucket ritsky-bucket-2025

# %%
# %%bash
#
# aws s3api get-bucket-acl \
# --bucket ritsky-bucket-2025
# Out:
# {
#     "Owner": {
#         "ID": "e634278e93e2ef73d33b56e2fc0de299a6d92f72954d413585807861e678560c"
#     },
#     "Grants": [
#         {
#             "Grantee": {
#                 "ID": "e634278e93e2ef73d33b56e2fc0de299a6d92f72954d413585807861e678560c",
#                 "Type": "CanonicalUser"
#             },
#             "Permission": "FULL_CONTROL"
#         }
#     ]
# }
